# %%
from statsbombpy import sb
import pandas as pd

# %%
competitions = sb.competitions()
# Out:
# c:\Users\emirc\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
competitions.head()
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-09-28T20:46:38.893391  2025-07-06T04:26:07.636270
# ...

# %%
competitions.shape
# Out:
# (75, 12)

# %%
competitions.columns.tolist()
# Out:
# ['competition_id',
#  'season_id',
#  'country_name',
#  'competition_name',
#  'competition_gender',
#  'competition_youth',
#  'competition_international',
#  'season_name',
#  'match_updated',
#  'match_updated_360',
#  'match_available_360',
#  'match_available']

# %%
competitions[["competition_id", "season_id", "country_name", "competition_name", "season_name"]].drop_duplicates().head(30)
# Out:
#     competition_id  season_id   country_name         competition_name  \
# 0                9        281        Germany            1. Bundesliga
# 1                9         27        Germany            1. Bundesliga
# 2             1267        107         Africa   African Cup of Nations
# 3               16          4         Europe         Champions League
# 4               16          1         Europe         Champions League
# 5               16          2         Europe         Champions League
# 6               16         27         Europe         Champions League
# 7               16         26         Europe         Champions League
# 8               16         25         Europe         Champions League
# 9               16         24         Europe         Champions League
# 10              16         23         Europe         Champions League
# 11              16         22         Europe         Champions League
# ...

# %%
world_cup = competitions[
    competitions["competition_name"] == "FIFA World Cup"
][["competition_id", "season_id", "country_name", "competition_name", "season_name"]].drop_duplicates()

world_cup
# Out:
#     competition_id  season_id   country_name competition_name season_name
# 29              43        106  International   FIFA World Cup        2022
# 30              43          3  International   FIFA World Cup        2018
# 31              43         55  International   FIFA World Cup        1990
# 32              43         54  International   FIFA World Cup        1986
# 33              43         51  International   FIFA World Cup        1974
# 34              43        272  International   FIFA World Cup        1970
# 35              43        270  International   FIFA World Cup        1962
# 36              43        269  International   FIFA World Cup        1958

# %%
competition_id = 43
season_id = 106

# %%
matches = sb.matches(competition_id=competition_id, season_id=season_id)
matches.head()
# Out:
# c:\Users\emirc\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off                     competition season  \
# 0   3857256  2022-12-02  21:00:00.000  International - FIFA World Cup   2022
# 1   3869151  2022-12-03  21:00:00.000  International - FIFA World Cup   2022
# 2   3857257  2022-11-30  17:00:00.000  International - FIFA World Cup   2022
# 3   3857258  2022-11-24  21:00:00.000  International - FIFA World Cup   2022
# 4   3857288  2022-11-26  12:00:00.000  International - FIFA World Cup   2022
#
#    home_team    away_team  home_score  away_score match_status  ...  \
# 0     Serbia  Switzerland           2           3    available  ...
# 1  Argentina    Australia           2           1    available  ...
# 2  Australia      Denmark           1           0    available  ...
# ...

# %%
matches.shape
# Out:
# (64, 22)

# %%
matches.columns.tolist()
# Out:
# ['match_id',
#  'match_date',
#  'kick_off',
#  'competition',
#  'season',
#  'home_team',
#  'away_team',
#  'home_score',
#  'away_score',
#  'match_status',
#  'match_status_360',
#  'last_updated',
#  'last_updated_360',
#  'match_week',
#  'competition_stage',
#  'stadium',
#  'referee',
#  'home_managers',
#  'away_managers',
#  'data_version',
#  'shot_fidelity_version',
#  'xy_fidelity_version']

# %%
matches[["match_id", "home_team", "away_team", "match_date"]].head(20)
# Out:
#     match_id     home_team    away_team  match_date
# 0    3857256        Serbia  Switzerland  2022-12-02
# 1    3869151     Argentina    Australia  2022-12-03
# 2    3857257     Australia      Denmark  2022-11-30
# 3    3857258        Brazil       Serbia  2022-11-24
# 4    3857288       Tunisia    Australia  2022-11-26
# 5    3857267       Ecuador      Senegal  2022-11-29
# 6    3869321   Netherlands    Argentina  2022-12-09
# 7    3857287       Uruguay  South Korea  2022-11-24
# 8    3869486       Morocco     Portugal  2022-12-10
# 9    3869685     Argentina       France  2022-12-18
# 10   3857260  Saudi Arabia       Mexico  2022-11-30
# 11   3857264        Poland    Argentina  2022-11-30
# 12   3857266        France      Denmark  2022-11-26
# 13   3857289     Argentina       Mexico  2022-11-26
# 14   3857269        Brazil  Switzerland  2022-11-28
# 15   3857294   Netherlands        Qatar  2022-11-29
# 16   3869254      Portugal  Switzerland  2022-12-06
# ...

# %%
match_id = matches.iloc[0]["match_id"]

# %%
events = sb.events(match_id=match_id)
events.head()
# Out:
# c:\Users\emirc\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#   bad_behaviour_card ball_receipt_outcome ball_recovery_recovery_failure  \
# 0                NaN                  NaN                            NaN
# 1                NaN                  NaN                            NaN
# 2                NaN                  NaN                            NaN
# 3                NaN                  NaN                            NaN
# 4                NaN                  NaN                            NaN
#
#   block_deflection block_offensive carry_end_location clearance_aerial_won  \
# 0              NaN             NaN                NaN                  NaN
# 1              NaN             NaN                NaN                  NaN
# 2              NaN             NaN                NaN                  NaN
# ...

# %%
events.shape
# Out:
# (3211, 91)

# %%
events.columns.tolist()
# Out:
# ['bad_behaviour_card',
#  'ball_receipt_outcome',
#  'ball_recovery_recovery_failure',
#  'block_deflection',
#  'block_offensive',
#  'carry_end_location',
#  'clearance_aerial_won',
#  'clearance_body_part',
#  'clearance_head',
#  'clearance_left_foot',
#  'clearance_right_foot',
#  'counterpress',
#  'dribble_nutmeg',
#  'dribble_outcome',
#  'duel_outcome',
#  'duel_type',
#  'duration',
#  'foul_committed_advantage',
#  'foul_committed_card',
#  'foul_committed_type',
#  'foul_won_advantage',
#  'foul_won_defensive',
#  'goalkeeper_body_part',
#  'goalkeeper_end_location',
#  'goalkeeper_outcome',
#  'goalkeeper_position',
#  'goalkeeper_technique',
#  'goalkeeper_type',
#  'id',
#  'index',
#  'injury_stoppage_in_chain',
#  'interception_outcome',
#  'location',
#  'match_id',
#  'minute',
#  'off_camera',
#  'out',
#  'pass_aerial_won',
#  'pass_angle',
#  'pass_assisted_shot_id',
#  'pass_body_part',
#  'pass_cross',
#  'pass_cut_back',
#  'pass_deflected',
# ...

# %%
events["type"].value_counts()
# Out:
# type
# Pass                 966
# Ball Receipt*        907
# Carry                667
# Pressure             177
# Ball Recovery         92
# Duel                  68
# Block                 40
# Clearance             36
# Foul Committed        35
# Foul Won              34
# Goal Keeper           30
# Shot                  26
# Miscontrol            25
# Interception          23
# Dispossessed          23
# Dribble               12
# Injury Stoppage       10
# Substitution           9
# Dribbled Past          6
# Referee Ball-Drop      4
# Half Start             4
# Half End               4
# Bad Behaviour          4
# Tactical Shift         2
# Starting XI            2
# Error                  2
# Player Off             1
# Player On              1
# Shield                 1
# Name: count, dtype: int64

# %%
events["team"].value_counts()
# Out:
# team
# Serbia         1723
# Switzerland    1488
# Name: count, dtype: int64

# %%
events["player"].value_counts().head(20)
# Out:
# player
# Strahinja Pavlović              250
# Saša Lukić                      192
# Nikola Milenković               182
# Granit Xhaka                    174
# Silvan Widmer                   168
# Filip Kostić                    155
# Dušan Tadić                     147
# Manuel Obafemi Akanji           144
# Ricardo Iván Rodríguez Araya    132
# Fabian Lukas Schär              132
# Breel-Donald Embolo             121
# Vanja Milinković Savić          120
# Aleksandar Mitrović             117
# Remo Freuler                    111
# Andrija Živković                110
# Xherdan Shaqiri                 105
# Djibril Sow                      96
# Ruben Vargas                     94
# Milos Veljkovic                  92
# Sergej Milinković-Savić          90
# Name: count, dtype: int64

# %%
events[["type", "team", "player", "minute", "location"]].head(20)
# Out:
#            type         team                 player  minute       location
# 0   Starting XI       Serbia                    NaN       0            NaN
# 1   Starting XI  Switzerland                    NaN       0            NaN
# 2    Half Start  Switzerland                    NaN       0            NaN
# 3    Half Start       Serbia                    NaN       0            NaN
# 4    Half Start       Serbia                    NaN      45            NaN
# 5    Half Start  Switzerland                    NaN      45            NaN
# 6          Pass  Switzerland    Breel-Donald Embolo       0   [61.0, 40.1]
# 7          Pass  Switzerland           Remo Freuler       0   [39.7, 45.5]
# 8          Pass  Switzerland          Silvan Widmer       0   [42.3, 72.2]
# 9          Pass  Switzerland     Fabian Lukas Schär       0   [23.1, 62.4]
# 10         Pass  Switzerland            Djibril Sow       0  [105.6, 74.4]
# ...

# %%
len(events)
events["type"].value_counts()
events["team"].value_counts()
events.groupby(["minute", "team"]).size().reset_index(name="count").head()
# Out:
#    minute         team  count
# 0       0       Serbia     16
# 1       0  Switzerland     32
# 2       1       Serbia     24
# 3       1  Switzerland     18
# 4       2       Serbia     28

# %%
events["player"].value_counts()
# Out:
# player
# Strahinja Pavlović              250
# Saša Lukić                      192
# Nikola Milenković               182
# Granit Xhaka                    174
# Silvan Widmer                   168
# Filip Kostić                    155
# Dušan Tadić                     147
# Manuel Obafemi Akanji           144
# Ricardo Iván Rodríguez Araya    132
# Fabian Lukas Schär              132
# Breel-Donald Embolo             121
# Vanja Milinković Savić          120
# Aleksandar Mitrović             117
# Remo Freuler                    111
# Andrija Živković                110
# Xherdan Shaqiri                 105
# Djibril Sow                      96
# Ruben Vargas                     94
# Milos Veljkovic                  92
# Sergej Milinković-Savić          90
# Gregor Kobel                     68
# Nemanja Gudelj                   58
# Nemanja Maksimović               55
# Dušan Vlahović                   52
# Edimilson Fernandes              51
# Luka Jović                       45
# ...

# %%
shots = events[events["type"] == "Shot"].copy()
shots["player"].value_counts()
# Out:
# player
# Granit Xhaka             3
# Breel-Donald Embolo      3
# Dušan Vlahović           3
# Aleksandar Mitrović      3
# Remo Freuler             2
# Xherdan Shaqiri          2
# Luka Jović               2
# Nikola Milenković        1
# Andrija Živković         1
# Ruben Vargas             1
# Fabian Lukas Schär       1
# Dušan Tadić              1
# Manuel Obafemi Akanji    1
# Christian Fassnacht      1
# Nemanja Radonjić         1
# Name: count, dtype: int64

# %%
shots = events[events["type"] == "Shot"].copy()
shots["shot_outcome"].value_counts()
shots[["team", "player", "minute", "location", "shot_outcome"]]
# Out:
#              team                 player  minute       location shot_outcome
# 2674  Switzerland           Granit Xhaka       0   [96.0, 38.8]      Blocked
# 2675  Switzerland    Breel-Donald Embolo       0  [113.1, 40.7]        Saved
# 2676  Switzerland           Granit Xhaka       0  [103.8, 41.9]        Saved
# 2677       Serbia      Nikola Milenković       4  [112.2, 36.8]        Off T
# 2678       Serbia       Andrija Živković      10   [97.8, 51.5]         Post
# 2679       Serbia         Dušan Vlahović      10  [115.4, 38.6]        Saved
# 2680  Switzerland           Remo Freuler      13  [107.8, 35.9]      Blocked
# 2681  Switzerland        Xherdan Shaqiri      19  [107.5, 50.6]         Goal
# 2682  Switzerland           Granit Xhaka      21   [97.3, 33.7]        Saved
# 2683       Serbia         Dušan Vlahović      22  [109.6, 35.4]        Saved
# 2684       Serbia    Aleksandar Mitrović      25  [108.3, 38.6]         Goal
# ...
